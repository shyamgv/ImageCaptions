# %%
pip install virtualenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !virtualenv /Users/shyam/projects/ImageSearch/virtual_env
# Out:
# created virtual environment CPython3.12.7.final.0-64 in 141ms
#   creator CPython3Posix(dest=/Users/shyam/projects/ImageSearch/virtual_env, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/Users/shyam/Library/Application Support/virtualenv)
#     added seed packages: pip==24.3.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source /Users/shyam/projects/ImageSearch/virtual_env/bin/activate; pip install Pypdf
# Out:
# ...
#   Using cached pypdf-5.1.0-py3-none-any.whl.metadata (7.2 kB)
# Using cached pypdf-5.1.0-py3-none-any.whl (297 kB)
# ...

# %%
pip install Pypdf
# Out:
# ...
#   Using cached pypdf-5.1.0-py3-none-any.whl.metadata (7.2 kB)
# Using cached pypdf-5.1.0-py3-none-any.whl (297 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade huggingface_hub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
import sys
#sys.path.append('/content/drive/MyDrive/colab_env/lib/python3.10/site-packages')
sys.path.clear()
sys.path.insert(0, '/opt/anaconda3/lib/python3.12/site-packages')
print(sys.path)
# Out:
# ['/opt/anaconda3/lib/python3.12/site-packages']

# %%
from pypdf import PdfReader

reader = PdfReader("/Users/shyam/projects/ImageSearch/DataFiles/Attachment.pdf")
number_of_pages = len(reader.pages)
print(number_of_pages)
# Out:
# 3
